# %% [markdown]
# # **Twitter Stock Sentiment**

# %% [markdown]
# # **1.0 INTRODUCTION**
# In addition to our **reinforcement learning** project, it would be interested to conduct **sentiment analysis** on tweets from twitter regarding companies from the Dow Jones Industrial Index. <br><br>
# This portion of the project will focus on building **classification models** to classify tweets into either **positive** or **negative** sentiments.

# %% [markdown]
# ## **1.1 Import Dependencies**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import nltk
from sklearn.feature_extraction.text import CountVectorizer

from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import re
from scipy.sparse.csr import csr_matrix
from collections import Counter
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from gensim.models import Word2Vec

# %%
DOW_30_TICKERS = [
    "AXP",
    "AMGN",
    "AAPL",
    "BA",
    "CAT",
    "CSCO",
    "CVX",
    "GS",
    "HD",
    "HON",
    "IBM",
    "INTC", 
    "JNJ",
    "KO",
    "JPM",
    "MCD",
    "MMM",
    "MRK",
    "MSFT",
    "NKE",
    "PG",
    "TRV",
    "UNH",
    "CRM",
    "VZ",
    "V",
    "WBA",
    "WMT",
    "DIS",
    "DOW"
]

# %% [markdown]
# ## **1.2 EDA**

# %% [markdown]
# Our data has already been cleaned prior to importing.

# %%
data = pd.read_csv('data/stock_data.csv', encoding= 'unicode_escape')
data.head()
# Out:
#                                                 Text  Sentiment
# 0  Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1   AAP MOVIE. 55% return for the FEA/GEED indica...          1
# 2   I'd be afraid to sho AMZN - they are looking ...          1
# 3                                  MNTA Over 12.00            1
# 4                                   OI  Over 21.37            1

# %% [markdown]
# The data simply consists of 2 columns: <br>
# - **text**, <br>
# - **sentiment**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5791 entries, 0 to 5790
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       5791 non-null   object
#  1   Sentiment  5791 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 90.6+ KB

# %% [markdown]
# Thankfully, no missing values. <br> <br>
# With classification modelling, it is important to view if there exist an **imbalance** of target values.

# %%
data['Sentiment'].value_counts(normalize=True)
# Out:
#  1    0.636332
# -1    0.363668
# Name: Sentiment, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (10, 4))
ax = sns.countplot(data = data, y = 'Sentiment')
ax.set_title('Twitter Sentiment', fontsize = 10)
ax.set_yticklabels(['Negative', 'Postive']);

# %% [markdown]
# Here we can see an imbalanced dataset, with 63% positive sentiments and 37% negative sentiments. We'll be mindful of this when we do our modelling. <br> <br>
# We can conduct some EDA to visualise other features.

# %% [markdown]
# **Character length vs sentiment**

# %%
data['character_length'] = data['Text'].apply(lambda x: len(x))

# %%
fig, ax = plt.subplots(figsize = (15, 10))
ax = sns.histplot(data = data, x = 'character_length', hue = 'Sentiment', kde = True)
ax.set_title('Character length by Sentiment');

# %% [markdown]
# **Word count vs sentiment**

# %%
data['word_count'] = data['Text'].apply(lambda x: len(x.split(' ')))

# %%
fig, ax = plt.subplots(figsize = (15, 10))
ax = sns.histplot(data = data, x = 'word_count', hue = 'Sentiment', kde = True)

# %% [markdown]
# # **2.0 DATA PREPARATION**

# %% [markdown]
# ## **2.1 Train test split**
# When doing our train test split, we need to remember that we have an imbalanced dataset. <br><br>
# When dealing with NLP, **SMOTE** is not an option. The only option is to **stratify** our test set so that distribution matches that of our original dataset.

# %%
X = data['Text']
y = data['Sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
y_train.value_counts(normalize=True)
# Out:
#  1    0.636426
# -1    0.363574
# Name: Sentiment, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
#  1    0.63605
# -1    0.36395
# Name: Sentiment, dtype: float64

# %% [markdown]
# ## **2.2 PREPROCESSING**
# When performing NLP, there are various prerocessing steps we must take before feeding the text into our classification model. Our steps will be:
# - **Lowercasing** the corpus
# - Removing **punctuation** om the corpus
# - **Tokenizing** our corpus
# - Removing **stop words** from our tokens
# - **Lemmatizing** each token

# %% [markdown]
# We first of all need to establish our **stop words**. We'll be utlising NLTKs library.

# %%
stopwords_list = nltk.corpus.stopwords.words('english')

# %% [markdown]
# We will also include all of the NYSE tickers.

# %%
NYSE = pd.read_csv('data/nyse-listed.csv')['ACT Symbol']
NYSE_TICKERS = NYSE.apply(lambda x: x.lower())

NASDAQ = pd.read_csv('data/nasdaq_constituents.csv')['Symbol']
NASDAQ_TICKERS = NASDAQ.apply(lambda x: x.lower())

DOW_30_TICKERS = [word.lower() for word in DOW_30_TICKERS]

complete_stopwords_list = list(stopwords_list) + list(NYSE_TICKERS) + DOW_30_TICKERS + list(NASDAQ_TICKERS) + ['stock', 'market', 'day', 'today', 'gmc', 'google', 'apple']

# %%
with open('NLP_models/complete_stopwords_list.pickle', 'wb') as handle:
    pickle.dump(complete_stopwords_list, handle, protocol = pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# We'll now make a simple function to summarise our preprocessing function.

# %%
def text_preprocessing(text):
    # lowercase
    text = text.lower()
    #remove ponctuation
    cleaned_text = re.sub("([^A-Za-z0-9|\s|[:punct:]]*)", '', text)
    # tokenize
    text_list = cleaned_text.split()
    # remove stopwords
    tokens = [word for word in text_list if word not in complete_stopwords_list]
    # lemmatize
    lemmatize = WordNetLemmatizer()
    lemmatized_list = [lemmatize.lemmatize(word) for word in tokens if len(lemmatize.lemmatize(word)) > 2]
    # rejoin our tokens into sentences
    words = ' '.join([word for word in lemmatized_list])
    return words

# %%
X_train_preprocessed = X_train.apply(lambda x: text_preprocessing(x))
X_test_preprocessed = X_test.apply(lambda x: text_preprocessing(x))

# %%
X_train_preprocessed
# Out:
# 3773                        falling explain money worried
# 4540                                        owe stop 1845
# 3137    earnings flushed conference flushed annual mee...
# 1058                                            dont walk
# 1704                                     gap backfill fie
#                               ...
# 5754           market crash plunge 1700 point early trade
# 5555    government begin fiscal year severe strain big...
# 2429                                      pphm going like
# 4468                grabbed otto 8250 put could breakdown
# 1962                                        dump progress
# Name: Text, Length: 4343, dtype: object

# %% [markdown]
# ## **2.3 Additional EDA**
# Now that our training and testing data have been preprocessed, we can further inspect our corpus by using a **count vectorizer** on the processed data.

# %%
cv = CountVectorizer(stop_words=complete_stopwords_list)

# %%
with open('NLP_models/count_vectorizer.pickle', 'wb') as handle:
    pickle.dump(cv, handle, protocol = pickle.HIGHEST_PROTOCOL)

# %%
X_train_count_vectorized = cv.fit_transform(X_train_preprocessed)

# %% [markdown]
# The **count_list** is the sum of each column from our sparse matrix where each column represents a token/word from our corpus.
# <br><br>
# The **word_list** shows us each token/word in our corpus and its corresponding index value within our sparse matrix.

# %%
count_list = np.array(X_train_count_vectorized.sum(axis = 0))
word_list = cv.vocabulary_

# %%
count_list
# Out:
# array([[1, 1, 1, ..., 4, 1, 3]], dtype=int64)

# %%
word_list
# Out:
# {'falling': 3320,
#  'explain': 3273,
#  'money': 4704,
#  'worried': 7037,
#  'owe': 5072,
#  'stop': 6238,
#  '1845': 404,
#  'earnings': 3022,
#  'flushed': 3454,
#  'conference': 2471,
#  'annual': 1695,
#  'meeting': 4605,
#  'buy': 2168,
#  'imho': 4007,
#  'dont': 2923,
#  'walk': 6882,
#  'gap': 3584,
#  'backfill': 1865,
#  'fie': 3383,
#  'anad': 1671,
#  'fib': 3378,
#  'level': 4397,
#  'watch': 6900,
#  'list': 4430,
#  'close': 2376,
#  'line': 4423,
#  'volume': 6849,
#  'full': 3546,
#  'average': 1836,
#  'yhoo': 7092,
#  'cramer': 2595,
#  'kiss': 4297,
#  'death': 2712,
#  'thanks': 6465,
#  'jds': 4218,
#  'nudge': 4891,
#  'kifmonster': 4288,
#  '30year': 720,
#  'treasury': 6629,
#  'yield': 7094,
#  'settled': 5905,
#  '1392': 234,
#  'highest': 3858,
#  'since': 5996,
#  'march': 4550,
#  'red': 5565,
#  'bar': 1890,
#  'size': 6010,
#  'ruin': 5759,
#  'target': 6411,
#  'point': 5268,
#  'made': 4510,
#  'higher': 3856,
#  'wait': 6875,
#  'first': 3420,
#  'like': 4416,
#  'entry': 3139,
#  '2264': 552,
#  '2155': 526,
#  'zcs': 7119,
#  'almost': 1636,
#  'hit': 3880,
#  'lossglad': 4480,
#  'heading': 3794,
#  'back': 1862,
#  'holding': 3895,
#  'ana': 1670,
#  'gae': 3567,
#  'vsn': 6862,
#  'wcx': 6914,
#  'need': 4799,
#  'ihi': 3992,
#  'call': 2193,
#  'eaders': 3007,
#  'acting': 1540,
#  'high': 3854,
#  'continues': 2518,
#  'highers': 3857,
#  'despite': 2795,
#  'week': 6933,
#  'global': 3646,
#  'fall': 3319,
#  'president': 5350,
#  'trump': 6658,
#  'issue': 4174,
#  'warning': 6893,
#  'spread': 6149,
#  'coronavirus': 2548,
#  'crisis': 2616,
#  'goair': 3655,
#  'decides': 2729,
#  'reduce': 5568,
#  'across': 1539,
#  'board': 2031,
#  'error': 3163,
#  'dataits': 2697,
#  'updated': 6756,
#  'share': 5927,
#  'outstanding': 5050,
#  'equal': 3156,
#  'million': 4651,
#  '21million': 535,
#  'mkt': 4679,
#  'bil': 1992,
#  'osing': 5017,
#  'looking': 4468,
#  'much': 4748,
#  'lower': 4487,
#  'price': 5362,
#  'miss': 4668,
#  'watchlist': 6905,
#  'shot': 5957,
#  'stocks': 6233,
#  'qih': 5480,
#  'soda': 6080,
#  'idea': 3974,
#  'favorite': 3343,
#  'setup': 5909,
#  'say': 5804,
#  'utility': 6787,
#  'boring': 2061,
#  'raising': 5507,
#  'right': 5713,
#  'around': 1768,
#  '3590': 791,
#  'eastman': 3030,
#  'stoploss': 6239,
#  '7346': 1293,
#  'beating': 1934,
#  '7385': 1300,
#  'tras': 6625,
#  'batir': 1911,
#  'sta': 6170,
#  'raised': 5506,
#  '342b': 766,
#  'pitchbook': 5232,
#  'situation': 6005,
#  'changed': 2285,
#  'marked': 4556,
#  'dropof': 2974,
#  'peeling': 5152,
#  '1900': 423,
#  'scoop': 5830,
#  'wall': 6883,
#  'street': 6261,
#  'force': 3487,
#  'citadel': 2341,
#  'security': 5863,
#  'firm': 3418,
#  'change': 2283,
#  'circuitbreaker': 2340,
#  'rule': 5760,
#  'buyer': 2172,
#  'seller': 5877,
#  'tube': 6666,
#  'decay': 2723,
#  'eps': 3153,
#  '1st': 451,
#  '74550': 1309,
#  'bounce': 2075,
#  'possible': 5302,
#  'extension': 3288,
#  'later': 4358,
#  'fed': 3361,
#  'program': 5398,
#  'suppo': 6332,
#  'economy': 3053,
#  'illustrate': 4000,
#  'sweeping': 6365,
#  'influence': 4071,
#  'estimate': 3186,
#  'slashed': 6030,
#  'squeezed': 6164,
#  'crash': 2599,
#  'pcyc': 5147,
#  'fresh': 3519,
#  'long': 4454,
#  'candle': 2209,
#  'barclays': 1891,
#  'upside': 6769,
#  'case': 2235,
#  'csod': 2644,
#  'year': 7079,
#  'end': 3112,
#  'based': 1899,
#  'cy14': 2667,
#  'revenue': 5689,
#  'quite': 5499,
#  'achievable': 1531,
#  'sma': 6049,
#  'cross': 2623,
#  'hasnt': 3778,
#  'october': 4935,
#  'pgnx': 5197,
#  '304': 702,
#  'weekly': 6935,
#  'triangle': 6638,
#  'fnfgscaling': 3459,
#  'going': 3659,
#  'premarket': 5338,
#  'somebody': 6093,
#  'know': 4307,
#  'something': 6096,
#  'thank': 6463,
#  'greedy': 3700,
#  'guy': 3736,
#  'bought': 2074,
#  '1199': 142,
#  'yesterday': 7087,
#  'sure': 6338,
#  'theyre': 6480,
#  'investor': 4148,
#  'approved': 1744,
#  'nevada': 4811,
#  'gambling': 3574,
#  'license': 4403,
#  'help': 3827,
#  'drive': 2968,
#  'rising': 5720,
#  'channel': 2289,
#  'top': 6568,
#  'bottom': 2070,
#  '28momentum': 673,
#  'indicator': 4056,
#  'turning': 6677,
#  'pause': 5131,
#  'scty': 5844,
#  'month': 4709,
#  'let': 4394,
#  'try': 6661,
#  'hod': 3891,
#  '1282': 195,
#  'pullback': 5443,
#  'another': 1697,
#  'reenter': 5573,
#  'mge': 4627,
#  'buying': 2174,
#  '268': 631,
#  '269': 632,
#  'executive': 3246,
#  'goldman': 3661,
#  'sachs': 5775,
#  'jpmorgan': 4254,
#  'balance': 1879,
#  'oppo': 5000,
#  'trading': 6607,
#  'profit': 5393,
#  'saf': 5778,
#  'mdso': 4589,
#  'ong': 4974,
#  '2751': 647,
#  'trailing': 6612,
#  '3767': 811,
#  'prior': 5373,
#  '3711': 804,
#  '3700': 801,
#  '3130': 725,
#  '2515': 596,
#  '2279': 555,
#  'sensex': 5886,
#  'nifty': 4835,
#  'struggle': 6276,
#  'positive': 5298,
#  'volatile': 6845,
#  'trade': 6600,
#  'qqq': 5482,
#  'elative': 3082,
#  'strength': 6262,
#  'easy': 3031,
#  'every': 3215,
#  'joker': 4246,
#  'thought': 6491,
#  'making': 4535,
#  'synonym': 6381,
#  'getting': 3623,
#  'rbi': 5524,
#  'inflation': 4068,
#  'covid19': 2586,
#  'outbreak': 5035,
#  'threatens': 6494,
#  'demand': 2767,
#  'acx': 1548,
#  'negative': 4803,
#  'algo': 1625,
#  'bringing': 2118,
#  'chance': 2282,
#  'cheap': 2303,
#  'bbh': 1917,
#  'hate': 3780,
#  'debt': 2716,
#  'hge': 3850,
#  'wrong': 7052,
#  '2250': 549,
#  'held': 3824,
#  'resistance': 5649,
#  'waited': 6876,
#  '11': 94,
#  '52am': 1104,
#  'placing': 5239,
#  'breath': 2108,
#  'easier': 3026,
#  'opening': 4991,
#  'kog': 4310,
#  'zaza': 7117,
#  'tsx': 6665,
#  'hao': 3761,
#  'pretty': 5355,
#  'strong': 6271,
#  'intraday': 4131,
#  '2695': 634,
#  'still': 6221,
#  'break': 2095,
#  'moody': 4715,
#  'warns': 6894,
#  'downgrading': 2945,
#  'tata': 6419,
#  'motor': 4730,
#  'fin': 3399,
#  '9mos': 1484,
#  'operational': 4994,
#  'decline': 2736,
#  '15million': 321,
#  '198': 439,
#  'pure': 5460,
#  'stupidity': 6286,
#  'germany': 3622,
#  'china': 2314,
#  'slowing': 6045,
#  'ignorance': 3988,
#  'bliss': 2018,
#  'imm': 4010,
#  'surge': 6339,
#  'minute': 4665,
#  'away': 1846,
#  'impo': 4020,
#  'slump': 6047,
#  'lowest': 4490,
#  'years': 7080,
#  'report': 5633,
#  'mot': 4727,
#  'waiting': 6878,
#  'vol': 6843,
#  '168': 351,
#  'happens': 3765,
#  'vng': 6840,
#  '278': 651,
#  'went': 6946,
#  'bathroom': 1910,
#  'normal': 4865,
#  'came': 2198,
#  '327': 748,
#  'poop': 5283,
#  'lol': 4452,
#  'continuing': 2519,
#  'rally': 5510,
#  'coveed': 2580,
#  '9650': 1465,
#  '9685': 1466,
#  'instead': 4105,
#  'classic': 2352,
#  'night': 4836,
#  'shyamalan': 5972,
#  'twist': 6684,
#  'got': 3674,
#  'recent': 5551,
#  'disappointment': 2850,
#  'term': 6450,
#  'upward': 6775,
#  'trend': 6630,
#  'macd': 4504,
#  'positiverising': 5300,
#  'cmf': 2389,
#  'nicely': 4831,
#  'compq': 2460,
#  'djia': 2903,
#  'spx': 6155,
#  'sca': 5809,
#  'retreat': 5682,
#  'jones': 4249,
#  'dismisses': 2865,
#  '14400': 257,
#  'added': 1552,
#  '8250': 1380,
#  'lotto': 4483,
#  'put': 5465,
#  'trap': 6623,
#  'coming': 2428,
#  'spy': 6157,
#  'eversal': 3213,
#  'crude': 2630,
#  'oil': 4960,
#  'third': 6487,
#  'straight': 6251,
#  'set': 5900,
#  'worst': 7040,
#  '1991': 445,
#  'targetdate': 6413,
#  'became': 1941,
#  'clear': 2357,
#  'rout': 5754,
#  'dgit': 2812,
#  'crack': 2592,
#  '997': 1480,
#  'sentiment': 5888,
#  'blink': 2017,
#  'faint': 3314,
#  'hea': 3790,
#  'bullish': 2151,
#  'earning': 3021,
#  'ready': 5534,
#  'rocket': 5732,
#  'within': 7006,
#  'nihd': 4837,
#  'likely': 4418,
#  'also': 1644,
#  'liking': 4419,
#  'action': 1541,
#  'others': 5024,
#  'dia': 2813,
#  'confirming': 2478,
#  'expectation': 3259,
#  'dndn': 2905,
#  'groupon': 3711,
#  'evisited': 3225,
#  'mission': 4671,
#  'epo': 3150,
#  'grumpy': 3717,
#  'old': 4965,
#  'accountant': 1521,
#  'south': 6116,
#  '50ma': 1075,
#  'crossing': 2625,
#  '200ma': 469,
#  'look': 4465,
#  'funny': 3554,
#  'check': 2307,
#  'xop': 7067,
#  'hedge': 3812,
#  'hotel': 3923,
#  'margin': 4551,
#  'switchboard': 6374,
#  'blowup': 2028,
#  'tomorrow': 6561,
#  'green': 3702,
#  'monthly': 4710,
#  'isisnet': 4168,
#  '7585290': 1318,
#  '493': 1032,
#  'finding': 3409,
#  'cloud': 2384,
#  'seems': 5871,
#  'unbelievable': 6708,
#  'record': 5558,
#  'jump': 4261,
#  'jobless': 4238,
#  'claim': 2349,
#  'course': 2578,
#  'tsa': 6664,
#  'electic': 3086,
#  'mainstream': 4524,
#  'soon': 6103,
#  'reminder': 5623,
#  'repo': 5632,
#  'friday': 3523,
#  'marketmaket': 4559,
#  'make': 4531,
#  'lot': 4482,
#  'till': 6520,
#  'fio': 3414,
#  'hard': 3769,
#  'comprehend': 2461,
#  'dump': 2990,
#  'asset': 1783,
#  'bubble': 2134,
#  'died': 2819,
#  'last': 4352,
#  'parabolic': 5107,
#  '700': 1263,
#  'cox': 2589,
#  '200ema': 467,
#  'bearish': 1928,
#  'environment': 3141,
#  'sign': 5983,
#  '2faced': 689,
#  'longs': 4460,
#  'purchased': 5458,
#  'ocz': 4936,
#  '2013': 478,
#  'vega': 6807,
#  'january': 4207,
#  '8th': 1425,
#  '11th': 144,
#  'progress': 5399,
#  'foreign': 3492,
#  'pull': 5442,
#  '12478': 178,
#  'crore': 2622,
#  'far': 3328,
#  'etfc': 3197,
#  'movement': 4736,
#  '197': 436,
#  'orbit': 5007,
#  'take': 6399,
#  '225': 548,
#  'eventually': 3210,
#  'descending': 2786,
#  'ower': 5073,
#  'didnt': 2817,
#  'overbought': 5054,
#  'triggered': 6642,
#  'earlier': 3018,
#  'bull': 2147,
#  'apr': 1748,
#  '425c': 900,
#  '1675': 349,
#  'laying': 4368,
#  'nearly': 4794,
#  'premium': 5340,
#  'continued': 2517,
#  'relative': 5605,
#  'moving': 4740,
#  'thursday': 6502,
#  'opec': 4989,
#  'signal': 5984,
#  'saudirussian': 5800,
#  'oilprice': 4962,
#  'war': 6889,
#  'xxia': 7069,
#  '5min': 1164,
#  'found': 3504,
#  'helpful': 3829,
#  '9period': 1485,
#  'ema': 3094,
#  'pink': 5226,
#  'using': 6783,
#  'protect': 5418,
#  'stopping': 6242,
#  '160': 323,
#  '130': 204,
#  'near': 4791,
#  'future': 3557,
#  'many': 4546,
#  'people': 5165,
#  'think': 6485,
#  'ip5s': 4153,
#  'biggersmaller': 1986,
#  'dick': 2815,
#  'tracy': 6598,
#  'micro': 4637,
#  'sized': 6011,
#  'faved': 3340,
#  'must': 4761,
#  'side': 5975,
#  'amazon': 1657,
#  'add': 1550,
#  '75000': 1312,
#  'pandemic': 5101,
#  'chairman': 2277,
#  'jerome': 4223,
#  'powell': 5315,
#  'central': 2270,
#  'bank': 1885,
#  'dexo': 2810,
#  'inverse': 4143,
#  'bounced': 2076,
#  'longer': 4455,
#  'electricity': 3088,
#  'use': 6779,
#  'due': 2984,
#  'lockdown': 4448,
#  'extend': 3285,
#  'loss': 4478,
#  'second': 5856,
#  'ftpdatingnear': 3540,
#  'multiday': 4751,
#  'downswing': 2949,
#  'esf': 3168,
#  'favored': 3342,
#  'zone': 7129,
#  '144200142375': 258,
#  'someone': 6095,
#  'tired': 6535,
#  'bji': 2006,
#  'fnfgopen': 3457,
#  'sell': 5876,
#  '822': 1376,
#  'pna': 5264,
#  'solid': 6089,
#  'dae': 2679,
#  'ony': 4982,
#  'biionyr': 1990,
#  'insanity': 4095,
#  'fb100': 3345,
#  'columnist': 2418,
#  'slammed': 6026,
#  'give': 3637,
#  'financial': 3405,
#  'trying': 6663,
#  'would': 7041,
#  'pullbackconsolidation': 5445,
#  'depopdating': 2780,
#  'slight': 6035,
#  'relocating': 5613,
#  'really': 5540,
#  'googlong': 3670,
#  '77871': 1334,
#  '77391': 1330,
#  'yhoolong': 7093,
#  'iafter': 3962,
#  '2027': 491,
#  '2016': 483,
#  'fit': 3425,
#  'adve': 1568,
#  'deal': 2709,
#  'marathon': 4549,
#  'petroleum': 5195,
#  'option': 5003,
#  'trader': 6605,
#  'bet': 1971,
#  'july': 4260,
#  'dollar': 2917,
#  'payday': 5135,
#  'sustained': 6358,
#  'momentum': 4699,
#  'expire': 3270,
#  'interest': 4117,
#  '480': 1015,
#  'uptrend': 6773,
#  'becoming': 1944,
#  'bear': 1927,
#  'hold': 3893,
#  '100': 31,
#  'contraction': 2522,
#  'larry': 4351,
#  'kudlow': 4322,
#  'adding': 1553,
#  'could': 2569,
#  'reopen': 5627,
#  'eight': 3077,
#  'tough': 6583,
#  'lossbut': 4479,
#  'msg': 4743,
#  'knicks': 4303,
#  'liked': 4417,
#  '111': 100,
#  '121': 152,
#  'dzz': 3004,
#  'plunge': 5260,
#  'sixmonth': 6007,
#  'strongest': 6273,
#  'echo': 3044,
#  'ogistics': 4956,
#  'ftw': 3541,
#  'short': 5955,
#  'everyone': 3218,
#  'playing': 5252,
#  'euro': 3200,
#  'bring': 2117,
#  'office': 4948,
#  'owner': 5077,
#  'longterm': 4464,
#  'stable': 6171,
#  'lease': 4378,
#  'hoped': 3909,
#  'building': 2145,
#  'become': 1942,
#  'skittish': 6019,
#  'bouncing': 2077,
#  'morning': 4721,
#  'nothing': 4875,
#  '1790s': 381,
#  'indian': 4051,
#  'banking': 1886,
#  'system': 6383,
#  'sound': 6112,
#  'shaktikanta': 5923,
#  'fill': 3394,
#  '750': 1311,
#  'least': 4379,
#  'test': 6455,
#  'technical': 6430,
#  'divergence': 2889,
#  'late': 4355,
#  '14month': 277,
#  '419': 888,
#  'flash': 3434,
#  'begin': 1949,
#  'upgrade2': 6760,
#  'outperf': 5041,
#  'mktperform': 4681,
#  'raise': 5505,
#  '1113': 101,
#  '1920': 431,
#  'royalty': 5757,
#  'surging': 6342,
#  'bb10': 1914,
#  'sale': 5786,
#  'kept': 4282,
#  'wishing': 7000,
#  'cousin': 2579,
#  'drop': 2973,
#  'hardest': 3772,
#  'history': 3879,
#  'climbing': 2371,
#  'stair': 6176,
#  '525': 1101,
#  'pivot': 5235,
#  'keep': 4279,
#  'cai': 2189,
#  '395': 840,
#  'setting': 5903,
#  'september': 5890,
#  'breaking': 2099,
#  '20k': 505,
#  'feb': 3358,
#  'offer': 4943,
#  '1400': 243,
#  '5th': 1166,
#  'broke': 2125,
#  '435': 924,
#  '437': 930,
#  'lead': 4370,
#  'slide': 6033,
#  'began': 1948,
#  'tue': 6667,
#  'fri': 3521,
#  'daily': 2680,
#  'chaos': 2290,
#  'mini': 4656,
#  'oversold': 5065,
#  'pwmo2': 5471,
#  'breakout': 2100,
#  'either': 3081,
#  'closing': 2382,
#  'basis': 1905,
#  'may': 4584,
#  'direction': 2844,
#  '50sma': 1077,
#  'wfm': 6955,
#  'respect': 5655,
#  'exit': 3252,
#  'calling': 2195,
#  'rotation': 5746,
#  'everything': 3220,
#  'everybody': 3216,
#  'happy': 3766,
#  'congrat': 2481,
#  'estaurant': 3184,
#  'tonight': 6564,
#  'flipping': 3445,
#  'never': 4812,
#  'meaty': 4598,
#  'obviusly': 4924,
#  'chipping': 2317,
#  'fair': 3315,
#  'trendfollowers': 6631,
#  'uncomfo': 6712,
#  'pharma': 5200,
#  'halol': 3748,
#  'impact': 4014,
#  'business': 2159,
#  'edge': 3061,
#  'nailed': 4771,
#  'unemployment': 6729,
#  'unlikely': 6739,
#  'show': 5960,
#  'watching': 6902,
#  'weakness': 6921,
#  '612year': 1185,
#  'longest': 4457,
#  'growth': 3716,
#  'counting': 2574,
#  'factory': 3304,
#  'output': 5044,
#  'grows': 3715,
#  'february': 3360,
#  'analyst': 1676,
#  'possibility': 5301,
#  'exists': 3251,
#  '13for2013': 238,
#  'leading': 4372,
#  'gainer': 3570,
#  'shed': 5936,
#  'taking': 6403,
#  'feeling': 3368,
#  'heop': 3837,
#  'luck': 4493,
#  'enfuegomaybe': 3120,
#  'icahn': 3968,
#  'loving': 4486,
#  '450': 960,
#  '25000': 591,
#  'praying': 5324,
#  'pin': 5223,
#  'shopdating': 5953,
#  '2150': 525,
#  'ooking': 4984,
#  'longside': 4461,
#  'delivery': 2765,
#  'come': 2423,
#  'push': 5462,
#  'bang': 1884,
#  'buck': 2137,
#  '795': 1344,
#  'crashing': 2600,
#  '1140': 112,
#  '1913': 427,
#  '1731': 368,
#  '1669': 345,
#  '1417': 248,
#  '1314': 206,
#  '1040': 57,
#  '940': 1451,
#  'floatingrate': 3447,
#  'taken': 6400,
#  'water': 6908,
#  'lately': 4357,
#  'explains': 3274,
#  'arnd': 1767,
#  '3940': 839,
#  '4010': 861,
#  'dip': 2839,
#  '1555': 301,
#  'might': 4644,
#  'amazing': 1656,
#  'ovti': 5071,
#  'szym': 6385,
#  'decent': 2727,
#  'multiple': 4753,
#  'timeframes': 6524,
#  'great': 3697,
#  'upwards': 6776,
#  'reversal': 5692,
#  'took': 6566,
#  'listen': 4432,
#  'mrkt': 4742,
#  'expect': 3258,
#  'way': 6910,
#  'notice': 4876,
#  'shakeout': 5921,
#  'reading': 5533,
#  '849': 1396,
#  'dot': 2930,
#  'monday': 4701,
#  'vxy': 6870,
#  'blowout': 2027,
#  'downside': 2948,
#  '5150': 1085,
#  'biggest': 1987,
#  'mistake': 4674,
#  'sticking': 6218,
#  'soas': 6075,
#  'stp': 6248,
#  'milwaukee': 4652,
#  'lay': 4366,
#  '300': 698,
#  'employee': 3106,
#  'mke': 4678,
#  'branch': 2090,
#  'shd': 5935,
#  'exiting': 3253,
#  'sitting': 6004,
#  'racket': 5502,
#  'medium': 4601,
#  'pumping': 5452,
#  'along': 1638,
#  'petm': 5193,
#  'ooks': 4985,
#  'weak': 6915,
#  '6340ish': 1199,
#  'ave': 1834,
#  'bottoming': 2071,
#  'moved': 4735,
#  'astx': 1792,
#  'popping': 5288,
#  'downtrendmini': 2953,
#  'wedge': 6929,
#  '4436': 952,
#  'gonna': 3663,
#  'statistical': 6195,
#  'agency': 1591,
#  'struggling': 6277,
#  'measure': 4594,
#  'poised': 5272,
#  'wake': 6880,
#  'eon': 3144,
#  '274': 643,
#  'solar': 6085,
#  'outlook': 5040,
#  'equity': 3159,
#  'alpha': 1641,
#  'chip': 2316,
#  'internet': 4124,
#  'everywhere': 3221,
#  'appealing': 1725,
#  '6570': 1219,
#  '6750': 1238,
#  'picked': 5212,
#  '6552': 1217,
#  'stayed': 6198,
#  'early': 3019,
#  'entire': 3137,
#  '200': 455,
#  'reminds': 5624,
#  'risk': 5722,
#  'reason': 5541,
#  'writes': 7049,
#  'jive': 4228,
#  '1680': 352,
#  'cut': 2663,
#  '1570': 309,
#  'explodes': 3276,
#  'implodes': 4018,
#  'minte': 4663,
#  'vid': 6826,
#  'nailing': 4772,
#  'subject': 6290,
#  '65mins': 1224,
#  'evening': 3208,
#  'potential': 5311,
#  'downtrend': 2951,
#  'nbelieveable': 4784,
#  'payment': 5137,
#  'vcs': 6806,
#  'chasing': 2300,
#  'easily': 3028,
#  'played': 5250,
#  'public': 5439,
#  'mastercard': 4573,
#  'planking': 5243,
#  'weeeee': 6931,
#  '535': 1115,
#  'penney': 5162,
#  'citigroup': 2344,
#  'following': 3474,
#  'lagging': 4337,
#  'actually': 1546,
#  'want': 6887,
#  '736737': 1297,
#  'egov': 3075,
#  '1662': 344,
#  'restingbasing': 5661,
#  'room': 5742,
#  'upper': 6767,
#  'bolly': 2044,
#  'absorb': 1508,
#  '1020': 47,
#  'latest': 4359,
#  'round': 5751,
#  'emergency': 3099,
#  'facility': 3301,
#  'expands': 3256,
#  'federal': 3362,
#  'reserve': 5640,
#  'footprint': 3485,
#  'credit': 2609,
#  'previously': 5359,
#  'avoid': 1840,
#  'head': 3791,
#  'shoulder': 5958,
#  'pattern': 5126,
#  'textbook': 6460,
#  'ceco': 2264,
#  'chase': 2299,
#  'major': 4528,
#  'spreading': 6150,
#  'aff': 1575,
#  'tape': 6410,
#  'mea': 4591,
#  'kdj': 4278,
#  'saying': 5805,
#  'monitoring': 4707,
#  'stricly': 6267,
#  '2825': 658,
#  '2850': 665,
#  'iphone': 4157,
#  'cheaper': 2304,
#  'ecosystem': 3056,
#  'company': 2444,
#  '360': 792,
#  'maybe': 4585,
#  '50b': 1067,
#  '410': 872,
#  'gowth': 3682,
#  'div': 2886,
#  'covered': 2583,
#  'blow': 2024,
#  'route': 5755,
#  'nyseaca': 4907,
#  '0700': 26,
#  'est': 3182,
#  'offerd': 4944,
#  '499': 1039,
#  'probability': 5379,
#  '2003': 458,
#  'trendline': 6634,
#  'mean': 4592,
#  'reversion': 5696,
#  '350': 777,
#  'vvs': 6866,
#  ...}

# %% [markdown]
# We'll now be combining the 2 together to get the **frequency** for each of our words.

# %%
frequency = [(word, count_list[0, i]) for word, i in word_list.items()]
frequency_df = pd.DataFrame(frequency, columns=['word', 'count'])

# %% [markdown]
# **Top 20** words

# %%
top_20 = frequency_df.sort_values(by = 'count', ascending=False)[:20]
top_20
# Out:
#             word  count
# 26        volume    220
# 55          like    210
# 5           stop    199
# 176         long    191
# 22         watch    155
# 75          high    149
# 12           buy    149
# 433         look    144
# 310        still    139
# 52        higher    137
# 64          back    132
# 311        break    130
# 79          week    128
# 87   coronavirus    124
# 249          ong    121
# 108        price    121
# 24         close    120
# 259       sensex    119
# 264        trade    119
# 50         point    117

# %%
fig, ax = plt.subplots(figsize = (15, 10))
ax = sns.barplot(data = top_20, x = 'word', y = 'count')
ax.set_title('Top 20 Most Frequent Words');

# %% [markdown]
# ### **Word Cloud**
# We can also create a word cloud to help visualise the data. We'll make 2 words clouds, one for positive sentiments and the other for negative sentiments.

# %% [markdown]
# **Positive Sentiment Word Cloud**

# %%
from PIL import Image
# data
positive_wc_data = data[data['Sentiment'] == 1]['Text'].map(text_preprocessing)
positive_wc_data = positive_wc_data.str.cat()

# Appearance
mask = np.array(Image.open('word_cloud/cloud.png'))

positive_wordcloud = WordCloud(background_color = None,
                                stopwords = complete_stopwords_list,
                                mask = mask,
                                color_func=lambda *args, **kwargs: (0,128,0))
                                
positive_wordcloud.generate(positive_wc_data)

# Plotting
fig, ax = plt.subplots(figsize = (15,10))
plt.imshow(positive_wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# **Negative Sentiment Word Cloud**

# %%
# data
negative_wc_data = data[data['Sentiment'] == -1]['Text'].map(text_preprocessing)
negative_wc_data = negative_wc_data.str.cat()

negative_wordcloud = WordCloud(background_color = None,
                                stopwords = complete_stopwords_list,
                                mask = mask,
                                color_func=lambda *args, **kwargs: (128,0,0))
                                
negative_wordcloud.generate(negative_wc_data)

# Plotting
fig, ax = plt.subplots(figsize = (15,10))
plt.imshow(negative_wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
plt.savefig(fig, 'test.png', transparent = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-600-9ad624364724> in <module>
# ----> 1 plt.savefig(fig, 'test.png', transparent = True)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     841 def savefig(*args, **kwargs):
#     842     fig = gcf()
# --> 843     res = fig.savefig(*args, **kwargs)
#     844     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     845     return res
#
# TypeError: savefig() takes 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %% [markdown]
# ### **Word Similarity**
# We can also view wthe similarity between words. We can do this buy utilising the **word2vec** model.
# <br><br>
# Our words of interest are **buy** and **sell**.

# %%
# tokenize our words
word2vec_X_train = X_train_preprocessed.apply(lambda x: x.split(' '))

# initialising our model
word2vec_model = Word2Vec(word2vec_X_train, window=5, min_count=2, workers = 4)

# training our w2v model
word2vec_model.train(word2vec_X_train, 
                     total_examples = word2vec_model.corpus_count, 
                     epochs = word2vec_model.epochs)

word2vec_model.save('NLP_models/w2v_model.h5')

# %%
word2vec_model.wv.most_similar(['buy'])
# Out:
# [('company', 0.9999390840530396),
#  ('money', 0.9999351501464844),
#  ('may', 0.9999327063560486),
#  ('share', 0.9999325275421143),
#  ('target', 0.9999293684959412),
#  ('even', 0.9999272227287292),
#  ('right', 0.9999239444732666),
#  ('would', 0.9999202489852905),
#  ('still', 0.9999202489852905),
#  ('since', 0.9999192953109741)]

# %%
word2vec_model.wv.most_similar(['sell'])
# Out:
# [('position', 0.9998749494552612),
#  ('long', 0.9998228549957275),
#  ('bull', 0.999822735786438),
#  ('take', 0.999819815158844),
#  ('bullish', 0.9998055696487427),
#  ('lot', 0.9998009204864502),
#  ('dont', 0.9997940063476562),
#  ('put', 0.9997819662094116),
#  ('check', 0.9997774362564087),
#  ('make', 0.9997761845588684)]

# %% [markdown]
# # **3.0 Traditional Modelling**
# For our modelling, we'll first be using a suite of traditional classification models and then we'll move onto using neural networks. <br><br>
# Our **baseline** model would be a scenario in which the algorithm guesses the majority sentiment each time i.e. **63% accuracy**.

# %% [markdown]
# ## **3.1 Untuned Traditional Classification Models**
# Our classification models will consist of 4 types:
# - ***Logistic Regression***
# - ***Naive Bayes***
# - ***Random Forest***
# - ***Gradient Boost***

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.metrics import confusion_matrix

from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_curve, auc, plot_confusion_matrix

# %% [markdown]
# We'll get the list of our models.

# %%
models = [
         {'name': 'Logistic_regresion',
         'classifier': LogisticRegression(fit_intercept=False, C=1e12, solver = 'liblinear', class_weight='balanced'),
         'val_accuracy_score': None
         },
         {'name': 'Naive_Bayes',
         'classifier': MultinomialNB(),
         'val_accuracy_score': None
         },
         {'name': 'Random_Forest',
         'classifier': RandomForestClassifier(n_jobs = 2, max_depth = 5, class_weight='balanced'),
         'val_accuracy_score': None
         },
         {'name': 'Gradient_boost',
         'classifier': GradientBoostingClassifier(),
         'val_accuracy_score': None}
         ]

# %% [markdown]
# We'll create a simple function to get our classification metrics and also plot a confusion matrix.

# %%
def model_evaluation(X_train,
                     y_train,
                     model):
        
    # Cross validation
    cross_val_model = cross_validate(
                        estimator = model['classifier'], 
                        X = X_train, 
                        y = y_train, 
                        scoring = ["accuracy", 'f1', 'recall', 'precision'],
                        return_train_score=True, 
                        cv=5)
                        

    # getting our scores
    model['val_accuracy_score'] = np.mean(cross_val_model['test_accuracy'])
    model['val_recall_score'] = np.mean(cross_val_model['test_recall'])
    model['val_f1_score'] = np.mean(cross_val_model['test_f1'])
    model['val_precision_score'] = np.mean(cross_val_model['test_precision'])

    # creating confusion matrix
    y_pred = cross_val_predict(
                                model['classifier'],
                                X = X_train,
                                y = y_train,
                                cv = 5
    )

    conf_mat = confusion_matrix(y_train, y_pred)

    plt.figure(figsize =(8, 6))
    sns.heatmap(conf_mat, annot = True, yticklabels = ['negative', 'positive'], xticklabels = ['negative', 'positive'], cmap = 'Blues', fmt = 'g')
    plt.xlabel('Predicted');
    plt.ylabel('Actual');
    plt.title(f"{model['name']} Confusion Matrix");
    plt.show()

    print(f"Model: {model['name']}")
    print(f"val accuracy: {round(model['val_accuracy_score'], 3)}")
    print(f"val recall: {round(model['val_recall_score'], 3)}")
    print(f"val f1: {round(model['val_f1_score'], 3)}")
    print(f"val precision: {round(model['val_precision_score'], 3)}")

    #Place everything into a dictionary to return
    summary_dict = {'name': model['name'],
                    'val_accuracy_score': model['val_accuracy_score'],
                    'val_recall_score': cross_val_model['test_recall'],
                    'val_f1_score': cross_val_model['test_f1'],
                    'val_precision_score': cross_val_model['test_precision'],
                    'confusion_matrix': conf_mat
                    }

    return summary_dict

# %%
summary_list = []

for model in models: 
    summary_list.append(model_evaluation(X_train_count_vectorized, y_train, model))
# Out:
# Model: Logistic_regresion
# val accuracy: 0.657
# val recall: 0.681
# val f1: 0.716
# val precision: 0.756
# Model: Naive_Bayes
# val accuracy: 0.716
# val recall: 0.815
# val f1: 0.785
# val precision: 0.758
# Model: Random_Forest
# val accuracy: 0.671
# val recall: 0.702
# val f1: 0.724
# val precision: 0.767
# Model: Gradient_boost
# val accuracy: 0.707
# val recall: 0.952
# val f1: 0.805
# val precision: 0.698

# %%
classifiers = [classifier['name'] for classifier in summary_list]
val_accuracy = [np.mean(classifier['val_accuracy_score']) for classifier in summary_list]
val_recall = [np.mean(classifier['val_recall_score']) for classifier in summary_list]
val_precision = [np.mean(classifier['val_precision_score']) for classifier in summary_list]
val_f1 = [np.mean(classifier['val_f1_score']) for classifier in summary_list]

val_summary_DataFrame = pd.DataFrame({'classifiers': classifiers, 
                                'val_accuracy': val_accuracy, 
                                'val_recall': val_recall,
                                'val_precision': val_precision,
                                'val_recall': val_recall,
                                'val_f1': val_f1})

val_summary_DataFrame = val_summary_DataFrame.sort_values(by = 'val_accuracy', ascending = False)
val_summary_DataFrame
# Out:
#           classifiers  val_accuracy  val_recall  val_precision    val_f1
# 1         Naive_Bayes      0.716318    0.814759       0.757782  0.785142
# 3      Gradient_boost      0.706879    0.951523       0.698015  0.805190
# 2       Random_Forest      0.670732    0.702180       0.766767  0.724102
# 0  Logistic_regresion      0.656912    0.680882       0.755738  0.716198

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(15,8)})
ax = sns.barplot(data = val_summary_DataFrame, x = 'classifiers', y = 'val_accuracy', palette=sns.color_palette("viridis"))
ax.axhline(0.63, linewidth = 3, color = 'r', label = 'baseline')
ax.set_title('Untuned Classification Models')
ax.set_xlabel('Model')
ax.set_ylabel('Accuracy')
plt.legend()
plt.show();

# %% [markdown]
# Great. Even with our traditional models being untuned, they were all able to outperform the baseline model.

# %% [markdown]
# ## **3.2 Tuned Traditional Classification Models**
# We'll incorporate **optuna** to help us tune our models.

# %%
import optuna

# %%
# sampler determines which hyperparameters to choose
sampler = optuna.samplers.TPESampler(seed = 42)

# pruner terminates a model early if it doesn't yield good results
pruner = optuna.pruners.HyperbandPruner()

# %%
tuned_models_summary = []

# %% [markdown]
# **Defining our objective function** <br><br>
# We'll be focusing on **maximising accuracy**. We'll only need to make 3 objective functions as the naive bayes classifier requires no tuning.

# %% [markdown]
# **Logistic Regression Tuning**

# %%
def lr_objective_function(trial):
  
  logreg_c = trial.suggest_float("C", 1e-10, 1e10, log=True)
  max_iter = trial.suggest_int('max_iter', 100, 500)

  clf = LogisticRegression(fit_intercept = False,
                           class_weight= 'balanced',
                           max_iter = max_iter,
                           C = logreg_c
                           )

  validation_accuracy = np.mean(cross_val_score(clf, X_train_count_vectorized, y_train, cv = 5))
  
  return validation_accuracy

study_lr = optuna.create_study(direction = 'maximize')
study_lr.optimize(lr_objective_function, n_trials = 100)
lr_best_params = study_lr.best_params

tuned_lr_model = LogisticRegression(fit_intercept = False,
                                    class_weight = 'balanced',
                                    max_iter = lr_best_params['max_iter'],
                                    C = lr_best_params['C']
                                    )
# Out:
# [I 2022-04-03 00:48:53,235] A new study created in memory with name: no-name-a35e03e0-eb3d-4035-8ddc-2758a1bb0d51
# [I 2022-04-03 00:48:54,440] Trial 0 finished with value: 0.6912169292528623 and parameters: {'C': 423.39048477066865, 'max_iter': 258}. Best is trial 0 with value: 0.6912169292528623.
# [I 2022-04-03 00:48:54,999] Trial 1 finished with value: 0.722301442942521 and parameters: {'C': 2.1989796882604513, 'max_iter': 396}. Best is trial 1 with value: 0.722301442942521.
# [I 2022-04-03 00:48:55,404] Trial 2 finished with value: 0.7216107290015008 and parameters: {'C': 3.1634812761869626, 'max_iter': 124}. Best is trial 1 with value: 0.722301442942521.
# [I 2022-04-03 00
  max_depth = trial.suggest_int("max_depth", 2, 32, log = True)
  criterion = trial.suggest_categorical("criterion", ['gini', 'entropy'])

  clf = RandomForestClassifier(class_weight='balanced',
                               criterion = criterion,
                               n_estimators = n_estimators,
                               max_depth = max_depth
  )

  validation_accuracy = np.mean(cross_val_score(clf, X_train_count_vectorized, y_train, cv = 5))

  return validation_accuracy

study_rf = optuna.create_study(direction = 'maximize')
study_rf.optimize(random_forest_objective_function, n_trials = 100)
rf_best_params = study_rf.best_params

tuned_rf_model = RandomForestClassifier(class_weight='balanced',
                                        criterion = rf_best_params['criterion'],
                                        n_estimators = rf_best_params['n_estimators'],
                                        max_depth = rf_best_params['max_depth']
                                        )
# Out:
# [I 2022-04-03 00:49:55,317] A new study created in memory with name: no-name-5455bddc-ba57-4fe6-8e1b-60eeb24cb1e6
# [I 2022-04-03 00:50:04,413] Trial 0 finished with value: 0.6965111654372577 and parameters: {'n_estimators': 578, 'max_depth': 5, 'criterion': 'entropy'}. Best is trial 0 with value: 0.6965111654372577.
# [I 2022-04-03 00:50:36,543] Trial 1 finished with value: 0.7154019928621806 and parameters: {'n_estimators': 812, 'max_depth': 17, 'criterion': 'gini'}. Best is trial 1 with value: 0.7154019928621806.
# [I 2022-04-03 00:51:04,573] Trial 2 finished with value: 0.7151726387128592 and parameters: {'n_estimators': 591, 'max_depth': 21, 'criterion': 'entropy'}. Best is trial 1 with value: 0.7154019928621806.
# [I 2022-04-03 00:51:10,555] Trial 3 finished with value: 0.7043513652537744 and parameters: {'n_estimators': 219, 'max_depth': 11, 'criterion': 'entropy'}. Best is trial 1 with value: 0.7154019928621806.
# [I 2022-04-03 00:51:18,845] Trial 4 finished with value: 0.6792571046756428 and parameters: {'n_estimators': 808, 'max_depth': 2, 'criterion': 'entropy'}. Best is trial 1 with value: 0.7154019928621806.
# [I 2022-04-03 00:51:46,726] Trial 5 finished with value: 0.7135610612335807 and parameters: {'n_estimators': 840, 'max_depth': 14, 'criterion': 'entropy'}. Best is trial 1 with value: 0.7154019928621806.
# [I 2022-04-03 00:51:49,346] Trial 6 finished with value: 0.6497703807013729 and parameters: {'n_estimators': 252, 'max_depth': 2, 'criterion': 'entropy'}. Best is trial 1 with value: 0.7154019928621806.
# [I 2022-04-03 00:51:51,487] Trial 7 finished with value: 0.666141759424732 and parameters: {'n_estimators': 177, 'max_depth': 3, 'criterion': 'entropy'}. Best is trial 1 with value: 0.7154019928621806.
# [I 2022-04-03 00:52:03,158] Trial 8 finished with value: 0.7045735603718454 and parameters: {'n_estimators': 935, 'max_depth': 3, 'criterion': 'gini'}. Best is trial 1 with value: 0.7154019928621806.
# [I 2022-04-03 00:52:34,100] Trial 9 finished with value: 0.7236894995572006 and parameters: {'n_estimators': 460, 'max_depth': 31, 'criterion': 'entropy'}. Best is trial 9 with value: 0.7236894995572006.
# [I 2022-04-03 00:52:59,465] Trial 10 finished with value: 0.7273716279637064 and parameters: {'n_estimators': 395, 'max_depth': 29, 'criterion': 'gini'}. Best is trial 10 with value: 0.7273716279637064.
# [I 2022-04-03
 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:25:24,522] Trial 88 finished with value: 0.7197761609562344 and parameters: {'n_estimators': 627, 'max_depth': 26, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:25:35,161] Trial 89 finished with value: 0.7084924671082288 and parameters: {'n_estimators': 548, 'max_depth': 7, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:25:54,567] Trial 90 finished with value: 0.7098752207367969 and parameters: {'n_estimators': 517, 'max_depth': 16, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:26:26,536] Trial 91 finished with value: 0.7234588196613513 and parameters: {'n_estimators': 497, 'max_depth': 29, 'criterion': 'gini'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:26:58,761] Trial 92 finished with value: 0.726683565515742 and parameters: {'n_estimators': 466, 'max_depth': 32, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:27:30,991] Trial 93 finished with value: 0.7188582140603375 and parameters: {'n_estimators': 464, 'max_depth': 32, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:28:07,325] Trial 94 finished with value: 0.7204674051958658 and parameters: {'n_estimators': 592, 'max_depth': 28, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:28:36,205] Trial 95 finished with value: 0.7213869429875962 and parameters: {'n_estimators': 521, 'max_depth': 25, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:28:57,975] Trial 96 finished with value: 0.7103376411257178 and parameters: {'n_estimators': 440, 'max_depth': 22, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:29:29,955] Trial 97 finished with value: 0.7204658143000323 and parameters: {'n_estimators': 488, 'max_depth': 30, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:29:55,545] Trial 98 finished with value: 0.7252978952448124 and parameters: {'n_estimators': 561, 'max_depth': 20, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.
# [I 2022-04-03 01:30:25,040] Trial 99 finished with value: 0.7204663445986436 and parameters: {'n_estimators': 551, 'max_depth': 24, 'criterion': 'entropy'}. Best is trial 52 with value: 0.7285234365471197.

# %% [markdown]
# **Gradient Boosting Tuning**

# %%
def gradient_boosting_objective_function(trial):
  
  n_estimators = trial.suggest_int("n_estimators", 10, 1000)
  max_depth = trial.suggest_int("max_depth", 2, 32, log = True)
  learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1)

  clf = GradientBoostingClassifier(learning_rate = learning_rate,
                                    n_estimators = n_estimators,
                                    max_depth = max_depth
  )

  validation_accuracy = np.mean(cross_val_score(clf, X_train_count_vectorized, y_train, cv = 5))

  return validation_accuracy

study_gb = optuna.create_study(direction = 'maximize')
study_gb.optimize(gradient_boosting_objective_function, n_trials = 100)
gb_best_params = study_gb.best_params

tuned_gb_model = GradientBoostingClassifier(learning_rate = gb_best_params['learning_rate'],
                                            n_estimators = gb_best_params['n_estimators'],
                                            max_depth = gb_best_params['max_depth']
                                            )
# Out:
# [I 2022-04-03 01:30:25,104] A new study created in memory with name: no-name-78a23931-b569-4f81-b10c-ff2a79e9598b
# [I 2022-04-03 01:33:54,099] Trial 0 finished with value: 0.6364264767490575 and parameters: {'n_estimators': 561, 'max_depth': 20, 'learning_rate': 1.051282333900783e-05}. Best is trial 0 with value: 0.6364264767490575.
# [I 2022-04-03 01:35:11,092] Trial 1 finished with value: 0.6364264767490575 and parameters: {'n_estimators': 483, 'max_depth': 4, 'learning_rate': 3.632123269814264e-05}. Best is trial 0 with value: 0.6364264767490575.
# [I 2022-04-03 01:37:28,257] Trial 2 finished with value: 0.7241505941995937 and parameters: {'n_estimators': 409, 'max_depth': 28, 'learning_rate': 0.04992338275994205}. Best is trial 2 with value: 0.7241505941995937.
# [I 2022-04-03 05:42:05,132] Trial 92 finished with value: 0.7299069856236048 and parameters: {'n_estimators': 933, 'max_depth': 10, 'learning_rate': 0.29480118907886355}. Best is trial 87 with value: 0.7347433089572739.
# [I 2022-04-03 05:44:52,299] Trial 93 finished with value: 0.7280649933977823 and parameters: {'n_estimators': 968, 'max_depth': 7, 'learning_rate': 0.12178682452454598}. Best is trial 87 with value: 0.7347433089572739.
# [I 2022-04-03 05:47:42,538] Trial 94 finished with value: 0.7289869175332631 and parameters: {'n_estimators': 914, 'max_depth': 9, 'learning_rate': 0.16479571236932886}. Best is trial 87 with value: 0.7347433089572739.
# [I 2022-04-03 05:50:36,770] Trial 95 finished with value: 0.7299056598770768 and parameters: {'n_estimators': 977, 'max_depth': 8, 'learning_rate': 0.22339089291336658}. Best is trial 87 with value: 0.7347433089572739.
# [I 2022-04-03 05:53:28,929] Trial 96 finished with value: 0.7319791274466653 and parameters: {'n_estimators': 995, 'max_depth': 7, 'learning_rate': 0.12414770521945073}. Best is trial 87 with value: 0.7347433089572739.
# [I 2022-04-03 05:56:06,724] Trial 97 finished with value: 0.7253034633802293 and parameters: {'n_estimators': 994, 'max_depth': 5, 'learning_rate': 0.6899996138738936}. Best is trial 87 with value: 0.7347433089572739.
# [I 2022-04-03 05:57:52,186] Trial 98 finished with value: 0.7259917909774994 and parameters: {'n_estimators': 549, 'max_depth': 10, 'learning_rate': 0.37458784176717574}. Best is trial 87 with value: 0.7347433089572739.
# [I 2022-04-03 06:00:44,299] Trial 99 finished with value: 0.7292154762346678 and parameters: {'n_estimators': 950, 'max_depth': 8, 'learning_rate': 0.04963366750163209}. Best is trial 87 with value: 0.7347433089572739.

# %% [markdown]
# **Putting it all together**

# %%
tuned_models = [
                {'name': 'Tuned Logistic_regresion',
                'classifier': tuned_lr_model
                },
                {'name': 'Tuned Random_Forest',
                'classifier': tuned_rf_model
                },
                {'name': 'Tuned Gradient_boost',
                'classifier': tuned_gb_model
                }
                ]

# %%
for model in tuned_models: 
    summary_list.append(model_evaluation(X_train_count_vectorized, y_train, model))
# Out:
# Model: Tuned Logistic_regresion
# val accuracy: 0.722
# val recall: 0.753
# val f1: 0.775
# val precision: 0.799
# Model: Tuned Random_Forest
# val accuracy: 0.724
# val recall: 0.813
# val f1: 0.789
# val precision: 0.768
# Model: Tuned Gradient_boost
# val accuracy: 0.733
# val recall: 0.869
# val f1: 0.806
# val precision: 0.752

# %%
classifiers = [classifier['name'] for classifier in summary_list]
val_accuracy = [np.mean(classifier['val_accuracy_score']) for classifier in summary_list]
val_recall = [np.mean(classifier['val_recall_score']) for classifier in summary_list]
val_precision = [np.mean(classifier['val_precision_score']) for classifier in summary_list]
val_f1 = [np.mean(classifier['val_f1_score']) for classifier in summary_list]

val_summary_DataFrame = pd.DataFrame({'classifiers': classifiers, 
                                    'val_accuracy': val_accuracy, 
                                    'val_recall': val_recall,
                                    'val_precision': val_precision,
                                    'val_recall': val_recall,
                                    'val_f1': val_f1})

# %%
val_summary_DataFrame = val_summary_DataFrame.sort_values(by = 'val_accuracy', ascending = False)
val_summary_DataFrame
# Out:
#                 classifiers  val_accuracy  val_recall  val_precision    val_f1
# 6      Tuned Gradient_boost      0.733358    0.868672       0.751636  0.805746
# 5       Tuned Random_Forest      0.724382    0.813325       0.768382  0.789302
# 4  Tuned Logistic_regresion      0.722302    0.752523       0.799262  0.775105
# 1               Naive_Bayes      0.716318    0.814759       0.757782  0.785142
# 3            Gradient_boost      0.706879    0.951523       0.698015  0.805190
# 2             Random_Forest      0.670732    0.702180       0.766767  0.724102
# 0        Logistic_regresion      0.656912    0.680882       0.755738  0.716198

# %%
for column in val_summary_DataFrame.columns[1:]:
    val_summary_DataFrame[column] = val_summary_DataFrame[column].apply(lambda x: round(x, 3))

# %%
val_summary_DataFrame.to_csv('data/NLP_summary_df.csv', index = False)

# %%
val_summary_DataFrame = pd.read_csv('data/NLP_summary_df.csv')

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(15,8)})
ax = sns.barplot(data = val_summary_DataFrame, x = 'classifiers', y = 'val_accuracy', palette=sns.color_palette("viridis"))
ax.axhline(0.63, linewidth = 3, color = 'r', label = 'baseline')
ax.set_title('Classification Models')
ax.set_xlabel('Model')
ax.set_ylabel('Accuracy')
plt.legend()
plt.show();

# %%
import plotly.express as px

fig = px.bar(
    val_summary_DataFrame,
    x = 'classifiers',
    y = 'val_accuracy',
    hover_data = ['val_recall', 'val_precision', 'val_f1'],
    color = 'val_accuracy',
    color_continuous_scale = px.colors.sequential.matter,
    title = 'NLP model summary',
    height = 720,
    width = 1280
)

fig.add_hline(
    y = 0.63,
    line_dash = 'dot',
    line_color = 'black'
)

fig.update_layout(
    yaxis = dict(
        title_text="Val Accuracy (%)"
    ),
    xaxis = dict(
        title_text = 'Classifiers'
    )
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-555-71fc998f818f> in <module>
#       8     color = 'val_accuracy'
#       9 )
# ---> 10 fig.add_hline(y = 0.63)
#      11 fig.show()
#
# AttributeError: 'Figure' object has no attribute 'add_hline'

# %%
fig.write_html('webapp/graphs/NLP_summary.html')

# %%
import pickle
with open('NLP_models/tuned_gradient_boosting_model.pickle', 'wb') as handle:
    pickle.dump(tuned_gb_model, handle, protocol = pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## **Using our best model on test data**

# %%
X_test_count_vectorized = cv.transform(X_test_preprocessed)
tuned_gb_model.fit(X_train_count_vectorized, y_train)
test_preds = tuned_gb_model.predict(X_test_count_vectorized)
test_accuracy = accuracy_score(y_test, test_preds)

# %% [markdown]
# **Test accuracy**

# %%
print(round(test_accuracy, 3))
# Out:
# 0.752

# %%
plt.figure(figsize = (15,10));

plot_confusion_matrix(
    tuned_gb_model, 
    X_test_count_vectorized, 
    y_test, 
    normalize = 'all',
    cmap = 'Blues',
    display_labels = ['negative', 'positive']
    );

plt.grid(False);

# %%
from joblib import dump, load

# %%
dump(tuned_gb_model, './NLP_models/NLP_model.joblib')
# Out:
# ['./NLP_models/NLP_model.joblib']

# %%
round(0, 3)
# Out:
# 0
